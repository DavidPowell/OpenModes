# %% [markdown]
# Calculate the eigencurrent expansion of a sphere.

# %%
# %pylab inline

import openmodes
from openmodes.basis import get_basis_functions
from openmodes.constants import c
import os.path as osp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sphere = openmodes.load_mesh(osp.join(openmodes.geometry_dir, "sphere.geo"), 
                          mesh_tol=0.2)

sim = openmodes.Simulation(name="test sphere")
sim.logger.propagate = True
sim.place_part(sphere)

# %% [markdown]
# ### Check if degenerate modes are orthogonal

# %%
num_modes = 3

s_start = 2j*np.pi*10e6
mode_s, mode_j = sim.part_singularities(s_start, num_modes, use_gram=True)

# %%
#sim.plot_solution([mode_j[0][:, 0]], 'mayavi')
#sim.plot_solution([mode_j[0][:, 1]], 'mayavi')
#sim.plot_solution([mode_j[0][:, 2]], 'mayavi')

# %%
basis = get_basis_functions(sphere, sim.basis_class)
G = basis.gram_matrix

print "magnitude of mode 0"
print mode_j[0][:, 0].dot(G.dot(mode_j[0][:, 0]))
print "overlap between modes"
print mode_j[0][:, 0].dot(G.dot(mode_j[0][:, 1]))
print mode_j[0][:, 0].dot(G.dot(mode_j[0][:, 2]))
print mode_j[0][:, 1].dot(G.dot(mode_j[0][:, 2]))
# Out:
# magnitude of mode 0
# (1+9.75646429965e-17j)
# overlap between modes
# (0.000567199120546-5.7773719396e-05j)
# (-0.000185716386079-0.000137639112253j)
# (0.000129624226012-9.65294585399e-06j)

# %% [markdown]
# ### Look at linearised problem

# %%
s_start = 2j*np.pi*10e6

from openmodes.eig import eig_linearised

Z = sim.impedance(s_start, sim.parts[0])

lin_s, _ = eig_linearised(Z, -1)

selected_s, _ = eig_linearised(Z, num_modes)
# Out:
# INFO:test sphere:Constructing 1185 loop-star basis functions
# 396 loops
# 789 stars
# 790 faces
# 1185 edges

# %%
# mesh 0.2
freq_s = lin_s/2/pi
selected_freq = selected_s/2/pi

loglog(abs(freq_s.real), abs(freq_s.imag), 'x')
loglog(abs(selected_freq.real), abs(selected_freq.imag), 'x')
ylabel('$freq$')

# %%
# mesh 0.5

freq_s = lin_s/2/pi
selected_freq = selected_s/2/pi

loglog(abs(freq_s.real), abs(freq_s.imag), 'x')
loglog(abs(selected_freq.real), abs(selected_freq.imag), 'x')
ylabel('$freq$')

# %%
num_modes = 9


s_start = 2j*np.pi*10e6
mode_s, mode_j = sim.part_singularities(s_start, num_modes, use_gram=True)

models = sim.construct_models(mode_s, mode_j)[0]
# Out:
# INFO:test sphere:Finding singularities for part (UUID('ff20b407-c61a-4b9a-9b6f-f1ca04fa33ac'),)
# INFO:test sphere:Converged after 11 iterations
# -4.3043e+06 +4.6087e+07j (linearised solution)
# -2.3970e+07 +4.1553e+07j (nonlinear solution)
# INFO:test sphere:Converged after 12 iterations
# -4.3050e+06 +4.6090e+07j (linearised solution)
# -2.3970e+07 +4.1553e+07j (nonlinear solution)
# INFO:test sphere:Converged after 9 iterations
# -4.3063e+06 +4.6094e+07j (linearised solution)
# -2.3975e+07 +4.1552e+07j (nonlinear solution)
# INFO:test sphere:Converged after 14 iterations
# -1.1619e+05 +1.0260e+08j (linearised solution)
# -3.3435e+07 +8.6739e+07j (nonlinear solution)
# INFO:test sphere:Converged after 14 iterations
# -1.1640e+05 +1.0268e+08j (linearised solution)
# -3.3478e+07 +8.6741e+07j (nonlinear solution)
# INFO:test sphere:Converged after 15 iterations
# -1.1675e+05 +1.0281e+08j (linearised solution)
# -3.3556e+07 +8.6744e+07j (nonlinear solution)
# INFO:test sphere:Converged after 20 iterations
# -1.1681e+05 +1.0286e+08j (linearised solution)
# -3.3556e+07 +8.6744e+07j (nonlinear solution)
# INFO:test sphere:Converged after 18 iterations
# -1.1680e+05 +1.0286e+08j (linearised solution)
# -3.3591e+07 +8.6755e+07j (nonlinear solution)
# INFO:test sphere:Converged after 18 iterations
# -4.7341e+02 +1.5370e+08j (linearised solution)
# -9.2225e+02 +1.3138e+08j (nonlinear solution)
# INFO:test sphere:Creating scalar model
# dlambda/ds = +3.3030e-10 -2.1631e-06
# Coefficients: [  2.17296866e+03   0.00000000e+00   0.00000000e+00   1.41230571e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +3.3031e-10 -2.1631e-06
# Coefficients: [  2.17296866e+03   0.00000000e+00   0.00000000e+00   1.41230571e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = -1.1366e-12 -2.1636e-06
# Coefficients: [  2.17350815e+03   0.00000000e+00   0.00000000e+00   1.41238784e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +2.2269e-07 -1.3259e-06
# Coefficients: [  2.68253970e+03   0.00000000e+00   1.08944094e+01   1.60085456e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +2.2153e-07 -1.3269e-06
# Coefficients: [  2.68333192e+03   0.00000000e+00   1.08669552e+01   1.60225367e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +2.1998e-07 -1.3301e-06
# Coefficients: [  2.68831751e+03   0.00000000e+00   1.08317932e+01   1.60688442e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +2.1998e-07 -1.3301e-06
# Coefficients: [  2.68831751e+03   0.00000000e+00   1.08317932e+01   1.60688442e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +2.1858e-07 -1.3303e-06
# Coefficients: [  2.68752696e+03   0.00000000e+00   1.08057787e+01   1.60711254e+00]
# INFO:test sphere:Creating scalar model
# dlambda/ds = +9.1819e-07 +5.7866e-09
# Coefficients: [  3.78984380e+03   5.32061423e-03   3.78984380e+01   0.00000000e+00]

# %%
num_freqs = 101
freqs = np.linspace(1e6, 100e6, num_freqs)
e_inc = np.array([1, 0, 0], dtype=np.complex128)
k_hat = np.array([0, 1, 0], dtype=np.complex128)

ext = np.empty(num_freqs, np.complex128)
ext_sem = np.empty((num_freqs, num_modes), np.complex128)
ext_eem = np.empty((num_freqs, num_modes), np.complex128)
ext_eem_direct = np.empty((num_freqs, num_modes), np.complex128)

z_sem = np.empty((num_freqs, num_modes), np.complex128)
z_eem = np.empty((num_freqs, num_modes), np.complex128)
z_eem_direct = np.empty((num_freqs, num_modes), np.complex128)

for freq_count, freq in enumerate(freqs):
    s = 2j*np.pi*freq
    jk_0 = s/c

    Z = sim.impedance(s)
    V = sim.source_plane_wave(e_inc, jk_0*k_hat)
        
    ext[freq_count] = np.vdot(V[0], Z[0][0].solve(V[0]))
    
    #eem_z, eem_j = Z.eigenmodes(num_modes, use_gram=True, start_j=mode_j)
    eem_z_d, eem_j_d = Z.eigenmodes(num_modes)
    z_eem_direct[freq_count] = eem_z_d[0]
    
    for mode in xrange(num_modes):
        #ext_eem[freq_count, mode] = np.vdot(V[0], eem_j[0][:, mode])*np.dot(V[0], eem_j[0][:, mode])/eem_z[0][mode]
        ext_eem_direct[freq_count, mode] = np.vdot(V[0], eem_j_d[0][:, mode])*np.dot(V[0], eem_j_d[0][:, mode])/eem_z_d[0][mode]
        
        ext_sem[freq_count, mode] = np.vdot(V[0], models[mode].solve(s, V[0]))
        z_sem[freq_count, mode] = models[mode].scalar_impedance(s)

# %%
figure(figsize=(8, 5))
subplot(121)
plot(freqs*1e-6, ext_eem_direct.real)
plot(freqs*1e-6, ext_sem.real, '--')
subplot(122)
plot(freqs*1e-6, ext_eem_direct.imag)
plot(freqs*1e-6, ext_sem.imag, '--')
suptitle('Modal extinction');

# %%
plt.figure(figsize=(8, 5))
plt.subplot(121)
plt.plot(freqs*1e-6, ext.real)
plt.plot(freqs*1e-6, np.sum(ext_sem.real, axis=1))
#plt.plot(freqs*1e-6, np.sum(ext_eem_direct.real, axis=1))
plt.subplot(122)
plt.plot(freqs*1e-6, ext.imag)
plt.plot(freqs*1e-6, np.sum(ext_sem.imag, axis=1))
#plt.plot(freqs*1e-6, np.sum(ext_eem_direct.imag, axis=1))
suptitle('Total extinction');

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(freqs*1e-6, z_sem.real)
xlabel('f (MHz)')
plt.subplot(122)
semilogy(freqs*1e-6, abs(z_sem.imag))
xlabel('f (MHz)')
suptitle('Impedance of SEM modes');

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(freqs*1e-6, z_eem_direct.real)
plt.subplot(122)
#plt.plot(freqs*1e-6, z_eem_direct.imag)
semilogy(freqs*1e-6, abs(z_eem_direct.imag))

suptitle('Impedance of EEM modes');

# %%
y_eem_direct = 1.0/z_eem_direct

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(freqs*1e-6, y_eem_direct.real)
plt.subplot(122)
plt.plot(freqs*1e-6, y_eem_direct.imag)
suptitle('Admittance of EEM modes');
# Out:
# [<matplotlib.lines.Line2D at 0xdaaf190>,
#  <matplotlib.lines.Line2D at 0x6dedbf0>,
#  <matplotlib.lines.Line2D at 0x6deddf0>,
#  <matplotlib.lines.Line2D at 0xd7d2f50>,
#  <matplotlib.lines.Line2D at 0x6df69b0>,
#  <matplotlib.lines.Line2D at 0x6df6f90>,
#  <matplotlib.lines.Line2D at 0xdb92a50>,
#  <matplotlib.lines.Line2D at 0xdb920b0>,
#  <matplotlib.lines.Line2D at 0xd6e1d10>,
#  <matplotlib.lines.Line2D at 0xd6e17b0>,
#  <matplotlib.lines.Line2D at 0xda97d50>,
#  <matplotlib.lines.Line2D at 0xdb00d50>,
#  <matplotlib.lines.Line2D at 0xda983d0>,
#  <matplotlib.lines.Line2D at 0xda98510>,
#  <matplotlib.lines.Line2D at 0xd6ff170>,
#  <matplotlib.lines.Line2D at 0xda98790>,
#  <matplotlib.lines.Line2D at 0xda988d0>,
#  <matplotlib.lines.Line2D at 0xda98a10>]

# %%
#y_eem_direct = 1.0/z_eem_direct
y_sem = 1.0/z_sem    

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(freqs*1e-6, y_eem_direct.real)
#plt.plot(freqs*1e-9, z_modes.real, '--')
plt.plot(freqs*1e-6, y_sem.real, '--')
plt.subplot(122)
#plt.semilogy(freqs*1e-9, abs(z_eem.imag), 'x')
#plt.semilogy(freqs*1e-9, abs(z_sem.imag), '--')
plt.plot(freqs*1e-6, y_eem_direct.imag)
plt.plot(freqs*1e-6, y_sem.imag, '--')
plt.show()
