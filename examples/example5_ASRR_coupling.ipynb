# %% [markdown]
# Example 5 - Coupling Coefficients of ASRRs
# ------------------------------------------
# Two split rings are placed in a broadside coupled configuration. The scalar model of each resonator is augmented by additional coefficients representing the coupling between them.
#
# In [D. A. Powell et al, Phys. Rev. B 82, 155128 (2010)](http://dx.doi.org/10.1103/PhysRevB.82.155128) similar coefficients were calculated under the quasi-static approximation for a single mode only. Here the effects of retardation and radiation losses are included, as are the contributions of multiple modes of each ring.

# %%
# %connect_info
# Out:
# {
#   "stdin_port": 52721,
#   "ip": "127.0.0.1",
#   "control_port": 52722,
#   "hb_port": 52723,
#   "signature_scheme": "hmac-sha256",
#   "key": "337f7d85-9c3a-4300-b022-215a986dc02e",
#   "shell_port": 52719,
#   "transport": "tcp",
#   "iopub_port": 52720
# }
#
# Paste the above JSON into a file, and connect with:
#     $> ipython <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> ipython <app> --existing kernel-3ec616ea-c252-4ce2-96fe-d1b960e3e674.json
# or even just:
#     $> ipython <app> --existing
# if this is the most recent IPython session you have started.

# %%
# %run plot_settings.ipy
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import openmodes
import openmodes.basis
from openmodes.constants import c
import os.path as osp

# %%
basis_class=openmodes.basis.LoopStarBasis
sim = openmodes.Simulation(basis_class=basis_class, name="example5", log_display_level=20)
mesh1, mesh2 = sim.load_mesh(osp.join(openmodes.geometry_dir, "asymmetric_ring.geo"), mesh_tol=0.25e-3)

ASRR = sim.place_part()

ring1 = sim.place_part(mesh1, parent=ASRR)
ring2 = sim.place_part(mesh2, parent=ASRR);
# Out:
# example5 - 2014-04-04 11:14:56,312 - Creating simulation
# Quadrature order 5
# Basis function class <class 'openmodes.basis.LoopStarBasis'>
# Log file c:\users\dap124\appdata\local\temp\2014-04-04--11-14-56wet3if.log
# example5 - 2014-04-04 11:14:56,313 - Meshing geometry c:\users\dap124\documents\2014\openmodes\openmodes\geometry\asymmetric_ring.geo with parameters {}
# example5 - 2014-04-04 11:14:56,497 - Loading mesh c:\users\dap124\appdata\local\temp\tmpsbhszm\asymmetric_ring.msh
# example5 - 2014-04-04 11:14:56,509 - Creating triangular mesh
# 282 nodes
# 444 triangles
# example5 - 2014-04-04 11:14:56,509 - Creating triangular mesh
# 318 nodes
# 499 triangles

# %%
from openmodes.visualise import plot_parts
plot_parts(sim.parts, view_angles=(90, 0))

# %%
num_modes = 4
start_s = 2j*np.pi*10e9

# %%
s_left, j_left = sim.singularities(start_s, num_modes, part=ring2)
s_right, j_right = sim.singularities(start_s, num_modes, part=ring1)
# Out:
# example5 - 2014-04-04 11:15:00,176 - Finding singularities for part 09ac39bd-9bce-4758-9d5c-50079d0e4122
# example5 - 2014-04-04 11:15:00,214 - Constructing 681 loop-star basis functions
# 183 loops
# 498 stars
# 499 faces
# 816 edges
# 135 unshared_edges
# 135 nodes on boundary
# 1 boundary contours
# example5 - 2014-04-04 11:15:06,828 - Converged after 4 iterations
# -6.8554e+08 +8.8176e+09j (linearised solution)
# -7.1863e+08 +8.6880e+09j (nonlinear solution)
# example5 - 2014-04-04 11:15:09,565 - Converged after 5 iterations
# -1.2560e+09 +1.7307e+10j (linearised solution)
# -1.6428e+09 +1.8504e+10j (nonlinear solution)
# example5 - 2014-04-04 11:15:11,265 - Converged after 5 iterations
# -4.7778e+08 +2.6020e+10j (linearised solution)
# -2.7393e+09 +2.8084e+10j (nonlinear solution)
# example5 - 2014-04-04 11:15:13,028 - Converged after 5 iterations
# -3.9174e+08 +3.5619e+10j (linearised solution)
# -3.7128e+09 +3.7342e+10j (nonlinear solution)
# example5 - 2014-04-04 11:15:13,032 - Finding singularities for part 343ef91b-a844-4773-908a-f9cd8afdde80
# example5 - 2014-04-04 11:15:13,068 - Constructing 607 loop-star basis functions
# 164 loops
# 443 stars
# 444 faces
# 725 edges
# 118 unshared_edges
# 118 nodes on boundary
# 1 boundary contours
# example5 - 2014-04-04 11:15:16,346 - Converged after 4 iterations
# -8.2504e+08 +9.8807e+09j (linearised solution)
# -9.0591e+08 +9.8357e+09j (nonlinear solution)
# example5 - 2014-04-04 11:15:17,688 - Converged after 5 iterations
# -1.1897e+09 +1.9569e+10j (linearised solution)
# -1.8665e+09 +2.0894e+10j (nonlinear solution)
# example5 - 2014-04-04 11:15:19,029 - Converged after 5 iterations
# -3.8355e+08 +2.9799e+10j (linearised solution)
# -2.9422e+09 +3.1878e+10j (nonlinear solution)
# example5 - 2014-04-04 11:15:20,388 - Converged after 5 iterations
# -3.7314e+08 +4.0719e+10j (linearised solution)
# -4.0332e+09 +4.2642e+10j (nonlinear solution)

# %%
from openmodes.eig import eig_linearised
Z = sim.impedance(start_s)[ASRR, ASRR]
lin_s, lin_j = eig_linearised(Z, np.arange(num_modes))

mode_s, mode_j = sim.singularities(start_s, num_modes, use_gram=True)
scalar_models = sim.construct_models(mode_s, mode_j);
# Out:
# example5 - 2014-04-04 11:15:34,584 - Finding singularities for part 8a143f5b-7d3c-4881-9e08-4650edcdd170
# example5 - 2014-04-04 11:15:56,717 - Converged after 4 iterations
# -5.7490e+08 +8.5053e+09j (linearised solution)
# -4.4643e+08 +8.4708e+09j (nonlinear solution)
# example5 - 2014-04-04 11:16:02,273 - Converged after 5 iterations
# -1.0573e+09 +1.0152e+10j (linearised solution)
# -1.3649e+09 +1.0263e+10j (nonlinear solution)
# example5 - 2014-04-04 11:16:08,427 - Converged after 5 iterations
# -1.2578e+09 +1.7397e+10j (linearised solution)
# -1.5550e+09 +1.8543e+10j (nonlinear solution)
# example5 - 2014-04-04 11:16:16,868 - Converged after 7 iterations
# -1.2377e+09 +1.9448e+10j (linearised solution)
# -2.1460e+09 +2.0998e+10j (nonlinear solution)
# example5 - 2014-04-04 11:16:18,602 - Creating scalar model
# dlambda/ds = +1.0168e-09 -1.8648e-10
# Coefficients: [  2.73122225e+02   0.00000000e+00   2.69314422e+00   2.88841556e-02]
# example5 - 2014-04-04 11:16:20,385 - Creating scalar model
# dlambda/ds = +6.7718e-10 -2.2450e-10
# Coefficients: [  2.26136280e+02   1.49897174e+00   2.10676559e+00   4.33469083e-02]
# example5 - 2014-04-04 11:16:22,243 - Creating scalar model
# dlambda/ds = +7.4741e-10 -1.2787e-10
# Coefficients: [  4.41549785e+02   3.52925803e+00   4.32096282e+00   3.79798940e-02]
# example5 - 2014-04-04 11:16:23,871 - Creating scalar model
# dlambda/ds = +6.0223e-10 -1.9461e-10
# Coefficients: [  4.07442233e+02   0.00000000e+00   3.86499361e+00   8.17950170e-02]

# %%
freqs = np.linspace(4e9, 20e9, 101)
#e_inc = np.array([1, 0, 0], dtype=np.complex128)
#k_hat = np.array([0, 1, 0], dtype=np.complex128)
k_hat = np.array([0, 0, 1.0], dtype=np.complex128)
e_inc = np.array([1, 1, 0], dtype=np.complex128)


extinction_sem = np.empty((len(freqs), num_modes), np.complex128)
extinction_red_whole = np.empty((len(freqs), num_modes), np.complex128)
extinction_red_parts = np.empty((len(freqs), num_modes*2), np.complex128)
extinction_tot = np.empty(len(freqs), np.complex128)

z_sem = np.empty((len(freqs), num_modes), np.complex128)
z_eem = np.empty((len(freqs), num_modes), np.complex128)


for freq_count, s in sim.iter_freqs(freqs):    
    Z = sim.impedance(s)
    V = sim.source_plane_wave(e_inc, k_hat*s/c)
    
    #lin_s, lin_j = eig_linearised(Z[ASRR, ASRR], np.arange(num_modes))
    
    z_mode, j_mode = Z.eigenmodes(num_modes=num_modes)#, start_j=lin_j)
    z_eem[freq_count] = z_mode
    projection = [(ASRR, mode_j)]
    impedance_red = Z.weight(projection)
    V_red = V.weight(projection)
    I_red_whole = impedance_red.solve(V_red)
    extinction_red_whole[freq_count] = V_red.conj()*I_red_whole
    #extinction_red_whole[freq_count] = V_red.conj()*V_red/z_mode

    z_left, j_eem_left = Z.eigenmodes(part=ring2, num_modes=num_modes, start_j=j_left)
    z_right, j_eem_right = Z.eigenmodes(part=ring1, num_modes=num_modes, start_j=j_right)

    projection = [(ring2, j_eem_left), (ring1, j_eem_right)]
    impedance_parts = Z.weight(projection)
    V_red = V.weight(projection)
    I_red_part = impedance_parts.solve(V_red)
    extinction_red_parts[freq_count] = V_red.conj()*I_red_part
    
    extinction_tot[freq_count] = np.vdot(V, Z.solve(V))
    
    for mode in xrange(num_modes):
        extinction_sem[freq_count, mode] = np.vdot(V, scalar_models[mode].solve(s, V))
        z_sem[freq_count, mode] = scalar_models[mode].scalar_impedance(s)
# Out:
# example5 - 2014-04-04 13:08:28,456 - Sweep frequency 0/101
# example5 - 2014-04-04 13:09:39,558 - Sweep frequency 10/101
# example5 - 2014-04-04 13:11:03,796 - Sweep frequency 20/101
# example5 - 2014-04-04 13:12:20,559 - Sweep frequency 30/101
# example5 - 2014-04-04 13:13:39,233 - Sweep frequency 40/101
# example5 - 2014-04-04 13:15:03,358 - Sweep frequency 50/101
# example5 - 2014-04-04 13:16:26,862 - Sweep frequency 60/101
# example5 - 2014-04-04 13:17:56,456 - Sweep frequency 70/101
# example5 - 2014-04-04 13:19:18,947 - Sweep frequency 80/101
# example5 - 2014-04-04 13:20:29,654 - Sweep frequency 90/101
# example5 - 2014-04-04 13:21:49,724 - Sweep frequency 100/101

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(freqs*1e-9, extinction_tot.real)
plt.plot(freqs*1e-9, np.sum(extinction_red_whole.real, axis=1), label='EEM whole')
#plt.plot(freqs*1e-9, np.sum(extinction_red_parts.real, axis=1), '--', label='EEM parts')
plt.plot(freqs*1e-9, np.sum(extinction_sem.real, axis=1), '-.', label='SEM whole')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.legend(loc='upper right')
plt.xlabel('f (GHz)')
plt.subplot(122)
plt.plot(freqs*1e-9, extinction_tot.imag)
plt.plot(freqs*1e-9, np.sum(extinction_red_whole.imag, axis=1))
#plt.plot(freqs*1e-9, np.sum(extinction_red_parts.imag, axis=1), '--')
plt.plot(freqs*1e-9, np.sum(extinction_sem.imag, axis=1), '-.')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.suptitle('Total extinction for EEM of whole system and of separate parts and SEM');

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(freqs*1e-9, extinction_red_whole.real)
plt.plot(freqs*1e-9, extinction_sem.real, '--')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.subplot(122)
plt.plot(freqs*1e-9, extinction_red_whole.imag)
plt.plot(freqs*1e-9, extinction_sem.imag, '--')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.suptitle('Extinction for each EEM/SEM mode of the whole system');

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(freqs*1e-9, z_eem.real)
plt.plot(freqs*1e-9, z_sem.real, '--')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.subplot(122)
plt.plot(freqs*1e-9, z_eem.imag)
plt.plot(freqs*1e-9, z_sem.imag, '--')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.suptitle('Impedance for each EEM/SEM mode of the whole system');

# %%
y_eem = 1/z_eem
y_sem = 1/z_sem

plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(freqs*1e-9, y_eem.real)
plt.plot(freqs*1e-9, y_sem.real, '--')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.subplot(122)
plt.plot(freqs*1e-9, y_eem.imag)
plt.plot(freqs*1e-9, y_sem.imag, '--')
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.suptitle('Admittance for each EEM/SEM mode of the whole system');

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(freqs*1e-9, extinction_sem.real)
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.subplot(122)
plt.plot(freqs*1e-9, extinction_sem.imag)
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.suptitle('Extinction for each SEM mode');

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(freqs*1e-9, extinction_red_parts.real)
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.subplot(122)
plt.plot(freqs*1e-9, extinction_red_parts.imag)
plt.xlim(freqs[0]*1e-9, freqs[-1]*1e-9)
plt.xlabel('f (GHz)')
plt.suptitle('Extinction for each EEM mode of the parts');

# %%
plt.pcolor(np.log10(abs(impedance_red[:])))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x00000000158A71C8>

# %%
Z_asrr = Z[ASRR, ASRR]
G = Z_asrr.basis_o.gram_matrix.toarray()
#orth = np.asarray(abs(j_mode.T.dot(G.dot(j_mode))))
orth = np.asarray(abs(j_mode.T.dot((j_mode))))

# %%
plt.pcolor(abs(orth))
plt.colorbar()
abs(orth)
# Out:
# array([[  1.00000000e+00,   6.82611325e-11,   6.02946386e-11,
#           4.04114674e-11],
#        [  6.82611325e-11,   1.00000000e+00,   1.22797359e-10,
#           7.79569658e-11],
#        [  6.02946386e-11,   1.22797359e-10,   1.00000000e+00,
#           3.68048579e-10],
#        [  4.04114674e-11,   7.79569658e-11,   3.68048579e-10,
#           1.00000000e+00]])
